# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('avocado.csv')
data
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
data.sample(15)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume       4046  \
# 13984          23  2016-07-17          1.49       7945.23     127.28
# 673            49  2015-01-18          0.99     808194.41  151976.70
# 12906          37  2016-04-10          1.20      13926.61    6289.57
# 6418            7  2017-11-12          1.19    3284210.00  699961.00
# 6558           41  2017-03-19          1.66     253838.30    5615.33
# 12932          11  2016-10-09          1.48       3479.15     133.02
# 8923            1  2018-03-18          0.92     552900.21   96399.53
# 4653           25  2016-07-03          1.05    2259572.01  684349.38
# 11160           6  2015-11-15          1.53       3846.37     110.01
# 8773            7  2018-02-04          0.98    1310671.51  897435.51
# 3647            7  2016-11-06          1.55     174837.42   40523.19
# 15413          36  2017-04-23          0.90      62384.23   12793.11
# 7413           48  2017-01-29          0.58    1380520.76  799387.73
# ...

# %% [markdown]
# # first the output = average price (Regression)

# %%
data = data.drop(['Unnamed: 0'],axis=1)

# %%
data.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
data.shape
# Out:
# (18249, 13)

# %%
data.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
plt.figure(figsize=(10,8))
sns.countplot('type',data=data)
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %% [markdown]
# both aRe almost same in the data

# %%
data['type'].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
plt.figure(figsize=(60,15))
sns.countplot('region',data=data,palette='twilight')
# Out:
# <AxesSubplot:xlabel='region', ylabel='count'>

# %% [markdown]
# the datalooks similar for all the region

# %%
data['region'].value_counts()
# Out:
# Albany                 338
# Sacramento             338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# Pittsburgh             338
# Plains                 338
# Portland               338
# RaleighGreensboro      338
# RichmondNorfolk        338
# Roanoke                338
# SanDiego               338
# Atlanta                338
# SanFrancisco           338
# Seattle                338
# SouthCarolina          338
# SouthCentral           338
# Southeast              338
# Spokane                338
# StLouis                338
# Syracuse               338
# Tampa                  338
# TotalUS                338
# West                   338
# NewYork                338
# NewOrleansMobile       338
# Nashville              338
# Midsouth               338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# BuffaloRochester       338
# ...

# %%
data=data.drop(['Date'],axis=1)
data
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  18249 non-null  float64
#  1   Total Volume  18249 non-null  float64
#  2   4046          18249 non-null  float64
#  3   4225          18249 non-null  float64
#  4   4770          18249 non-null  float64
#  5   Total Bags    18249 non-null  float64
#  6   Small Bags    18249 non-null  float64
#  7   Large Bags    18249 non-null  float64
#  8   XLarge Bags   18249 non-null  float64
#  9   type          18249 non-null  object
#  10  year          18249 non-null  int64
#  11  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(2)
# memory usage: 1.7+ MB

# %%
data['year'].value_counts()
# Out:
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: year, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot('year',data=data,palette='twilight')
# Out:
# <AxesSubplot:xlabel='year', ylabel='count'>

# %% [markdown]
# no of sales of avocadoes is max in the year 2017 and min in 2018

# %%
plt.figure(figsize=(8,5))
sns.boxplot('4770',data=data)
# Out:
# <AxesSubplot:xlabel='4770'>

# %% [markdown]
# we cant make boxplot to analyse the data in these types of columns

# %%
plt.figure(figsize=(20,10))
sns.stripplot(x='4770',y='region',data=data)
# Out:
# <AxesSubplot:xlabel='4770', ylabel='region'>

# %% [markdown]
# so clearly PLU4770 avocado moslty sales in the south centarl

# %%
plt.figure(figsize=(20,10))
sns.stripplot(x='4046',y='region',data=data)
# Out:
# <AxesSubplot:xlabel='4046', ylabel='region'>

# %% [markdown]
# so PLU4046 avocadoes mostly sold in california

# %%
plt.figure(figsize=(20,10))
sns.stripplot(x='4225',y='region',data=data)
# Out:
# <AxesSubplot:xlabel='4225', ylabel='region'>

# %% [markdown]
# as graph shows most PLU4225 avocadoes sold in the Northeast region

# %%
plt.figure(figsize=(20,10))
sns.stripplot(x='year',y='Small Bags',data=data)
# Out:
# <AxesSubplot:xlabel='year', ylabel='Small Bags'>

# %% [markdown]
# small bags sold in the year 2017 is max and in 2015 is min

# %%
plt.figure(figsize=(10,5))
sns.stripplot(x='year',y='Large Bags',data=data)
# Out:
# <AxesSubplot:xlabel='year', ylabel='Large Bags'>

# %% [markdown]
# large bags of avocadoes sold in the year 2016 is max and min in 2018

# %%
plt.figure(figsize=(10,5))
sns.stripplot(x='year',y='XLarge Bags',data=data)
# Out:
# <AxesSubplot:xlabel='year', ylabel='XLarge Bags'>

# %% [markdown]
# Xlarge bags of avocadoes sold in the year 2016 is max and min in 2018

# %%
data.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          type  \
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507      0.499918
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
var_mode = ['type','region']

for i in var_mode:
    data[i] = le.fit_transform(data[i])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  18249 non-null  float64
#  1   Total Volume  18249 non-null  float64
#  2   4046          18249 non-null  float64
#  3   4225          18249 non-null  float64
#  4   4770          18249 non-null  float64
#  5   Total Bags    18249 non-null  float64
#  6   Small Bags    18249 non-null  float64
#  7   Large Bags    18249 non-null  float64
#  8   XLarge Bags   18249 non-null  float64
#  9   type          18249 non-null  int32
#  10  year          18249 non-null  int64
#  11  region        18249 non-null  int32
# dtypes: float64(9), int32(2), int64(1)
# memory usage: 1.5 MB

# %%
data.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# 4046             -0.208317      0.977863  1.000000  0.926110  0.833389
# 4225             -0.172928      0.974181  0.926110  1.000000  0.887855
# 4770             -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
# type              0.615845     -0.232434 -0.225819 -0.232289 -0.210027
# year              0.093197      0.017193  0.003353 -0.009559 -0.036531
# region           -0.011716      0.174176  0.192073  0.145726  0.095252
#
# ...

# %%
plt.figure(figsize=(20,9))
sns.heatmap(data.corr(),annot= True,linewidth=0.1,linecolor='black',fmt="0.2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Average price is least related with the region..
#
# clearly shows there is many columns tht are highly correlated with each other so lets chk the vif values and chck for multicollinearity

# %%
df_nom = data[['Total Volume','4046','4225','4770','Total Bags','Small Bags','Large Bags','XLarge Bags','year']].copy()

# %%
df_nom
# Out:
#        Total Volume     4046       4225    4770  Total Bags  Small Bags  \
# 0          64236.62  1036.74   54454.85   48.16     8696.87     8603.62
# 1          54876.98   674.28   44638.81   58.33     9505.56     9408.07
# 2         118220.22   794.70  109149.67  130.50     8145.35     8042.21
# 3          78992.15  1132.00   71976.41   72.58     5811.16     5677.40
# 4          51039.60   941.48   43838.39   75.78     6183.95     5986.26
# ...             ...      ...        ...     ...         ...         ...
# 18244      17074.83  2046.96    1529.20    0.00    13498.67    13066.82
# 18245      13888.04  1191.70    3431.50    0.00     9264.84     8940.04
# 18246      13766.76  1191.92    2452.79  727.94     9394.11     9351.80
# 18247      16205.22  1527.63    2981.04  727.01    10969.54    10919.54
# 18248      17489.58  2894.77    2356.13  224.53    12014.15    11988.14
#
#        Large Bags  XLarge Bags  year
# 0           93.25          0.0  2015
# ...

# %%
df_cat = data[['AveragePrice','type','region']].copy()
df_cat
# Out:
#        AveragePrice  type  region
# 0              1.33     0       0
# 1              1.35     0       0
# 2              0.93     0       0
# 3              1.08     0       0
# 4              1.28     0       0
# ...             ...   ...     ...
# 18244          1.63     1      53
# 18245          1.71     1      53
# 18246          1.87     1      53
# 18247          1.93     1      53
# 18248          1.62     1      53
#
# [18249 rows x 3 columns]

# %%
plt.figure(figsize = (25,30),facecolor = "red")
plotnumber = 1
for column in df_nom:
    if plotnumber<=9:
        ax=plt.subplot(6,3,plotnumber)
        sns.distplot(df_nom[column])
        plt.xlabel(column,fontsize=14)
        
    plotnumber+=1
plt.show()

# %%
df_nom.skew()
# Out:
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# year             0.215339
# dtype: float64

# %% [markdown]
# there are too much skewness present in that continous column as the value is more thn 1

# %%
df_s = np.cbrt(df_nom)

# %%
df_s.skew()
# Out:
# Total Volume    2.236143
# 4046            2.277861
# 4225            2.130378
# 4770            2.316048
# Total Bags      2.302176
# Small Bags      2.217682
# Large Bags      2.186514
# XLarge Bags     2.842255
# year            0.214909
# dtype: float64

# %%
plt.figure(figsize = (20,15),facecolor = "red")
plotnumber = 1
for column in df_s:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(df_s[column])
        plt.xlabel(column,fontsize=14)
        
    plotnumber+=1
plt.show()

# %% [markdown]
# we remove the skewness by cbrt method but as we used log method it shows in many columns NAN tht is not good thts y we used cbrt

# %%
plt.figure(figsize = (15,10))
plotnumber = 1
for column in df_nom:
    if plotnumber<=9:
        plt.subplot(3,3,plotnumber)
        ax=sns.boxplot(data=df_nom[column])
        plt.xlabel(column,fontsize=15)
        
    plotnumber+=1
plt.show()

# %% [markdown]
# this boxplot data shows in these columns therre might be extreme level of outliers present

# %%
data_loss = ((18249-17782)/18249)*100
data_loss
# Out:
# 2.55904433119623

# %%
# seprating the columns into features and target

x= data.drop("AveragePrice",axis=1)
y= data["AveragePrice

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_scaled= sc.fit_transform(x)

# %%
x_scaled.shape[1]
# Out:
# 11

# %%
vif = pd.DataFrame()
vif["vif"] = [variance_inflation_factor(x_scaled,i) for i in range(x_scaled.shape[1])]
vif["features"] = x.columns

vif
# Out:
#              vif      features
# 0   4.924577e+09  Total Volume
# 1   6.607069e+08          4046
# 2   5.986551e+08          4225
# 3   4.768429e+06          4770
# 4   2.370316e+14    Total Bags
# 5   1.364727e+14    Small Bags
# 6   1.448103e+13    Large Bags
# 7   7.620884e+10   XLarge Bags
# 8   1.061696e+00          type
# 9   1.047911e+00          year
# 10  1.069488e+00        region

# %% [markdown]
# The vif value is much more higher there means there is multicollinearity present hnce we have to drop some columns

# %%
data = data.drop(['Total Volume','Total Bags'],axis=1)
data.head()
# Out:
#    AveragePrice     4046       4225    4770  Small Bags  Large Bags  \
# 0          1.33  1036.74   54454.85   48.16     8603.62       93.25
# 1          1.35   674.28   44638.81   58.33     9408.07       97.49
# 2          0.93   794.70  109149.67  130.50     8042.21      103.14
# 3          1.08  1132.00   71976.41   72.58     5677.40      133.76
# 4          1.28   941.48   43838.39   75.78     5986.26      197.69
#
#    XLarge Bags  type  year  region
# 0          0.0     0  2015       0
# 1          0.0     0  2015       0
# 2          0.0     0  2015       0
# 3          0.0     0  2015       0
# 4          0.0     0  2015       0

# %%
from scipy.stats import zscore

# %%
z_score = zscore(data)
abs_z_score = np.abs(z_score)
threshold=3
np.where(abs_z_score>3)
# Out:
# (array([  346,   359,   780, ..., 17304, 17402, 17428], dtype=int64),
#  array([1, 1, 6, ..., 0, 0, 0], dtype=int64))

# %%
fil_entry = (abs_z_score<3).all(axis=1)
df = data[fil_entry]
df
# Out:
#        AveragePrice     4046       4225    4770  Small Bags  Large Bags  \
# 0              1.33  1036.74   54454.85   48.16     8603.62       93.25
# 1              1.35   674.28   44638.81   58.33     9408.07       97.49
# 2              0.93   794.70  109149.67  130.50     8042.21      103.14
# 3              1.08  1132.00   71976.41   72.58     5677.40      133.76
# 4              1.28   941.48   43838.39   75.78     5986.26      197.69
# ...             ...      ...        ...     ...         ...         ...
# 18244          1.63  2046.96    1529.20    0.00    13066.82      431.85
# 18245          1.71  1191.70    3431.50    0.00     8940.04      324.80
# 18246          1.87  1191.92    2452.79  727.94     9351.80       42.31
# 18247          1.93  1527.63    2981.04  727.01    10919.54       50.00
# 18248          1.62  2894.77    2356.13  224.53    11988.14       26.01
#
#        XLarge Bags  type  year  region
# 0              0.0     0  2015       0
# ...

# %%
data_loss = ((18249-17651)/18249)*100
data_loss
# Out:
# 3.276891884486821

# %%
df.corr()
# Out:
#               AveragePrice      4046      4225      4770  Small Bags  \
# AveragePrice      1.000000 -0.333577 -0.243988 -0.243465   -0.275771
# 4046             -0.333577  1.000000  0.565118  0.492127    0.706800
# 4225             -0.243988  0.565118  1.000000  0.620221    0.778761
# 4770             -0.243465  0.492127  0.620221  1.000000    0.571512
# Small Bags       -0.275771  0.706800  0.778761  0.571512    1.000000
# Large Bags       -0.270915  0.561060  0.451711  0.323747    0.593155
# XLarge Bags      -0.152669  0.415432  0.392030  0.495976    0.597700
# type              0.613150 -0.341376 -0.383138 -0.321809   -0.367593
# year              0.091704 -0.034636 -0.040234 -0.082054    0.086639
# region           -0.003242  0.119067  0.011002 -0.095972    0.065976
#
#               Large Bags  XLarge Bags      type      year    region
# AveragePrice   -0.270915    -0.152669  0.613150  0.091704 -0.003242
# 4046            0.561060     0.415432 -0.341376 -0.034636  0.119067
# ...

# %%
# now data looks good for our model building

# %% [markdown]
# # first uses REGRESSION ALGO FOR FINDING THE AVERAGE PRICE

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=i)
    lr.fit(x_train,y_train)
    pred_train = lr.predict(x_train)
    pred_test = lr.predict(x_test)
    print("At random state",i , "the training accuracy is",  {r2_score(y_train,pred_train)})
    
    print("At random state",i , "the testing accuracy is" , {r2_score(y_test,pred_test)})
    print("\n")
# Out:
# At random state 0 the training accuracy is {0.4066804940474318}
# At random state 0 the testing accuracy is {0.4055697163106331}
#
#
# At random state 1 the training accuracy is {0.4049931577581609}
# At random state 1 the testing accuracy is {0.41157274964113166}
#
#
# At random state 2 the training accuracy is {0.410172201268848}
# At random state 2 the testing accuracy is {0.39571698027293023}
#
#
# At random state 3 the training accuracy is {0.4061990064768648}
# At random state 3 the testing accuracy is {0.4080075178807252}
#
#
# At random state 4 the training accuracy is {0.40995332486314606}
# At random state 4 the testing accuracy is {0.39662840221635}
#
#
# At random state 5 the training accuracy is {0.40733390637050726}
# At random state 5 the testing accuracy is {0.40346246929222596}
#
#
# At random state 6 the training accuracy is {0.40385798927304584}
# At random state 6 the testing accuracy is {0.41507301694168297}
#
#
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=27)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test = lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.4210835103902695

# %%
from sklearn.model_selection import cross_val_score

# %%
cv_score = cross_val_score(lr,x,y,cv=7)
cv_mean = cv_score.mean()
cv_mean
# Out:
# 0.013129711461185054

# %%
from sklearn import metrics

# %%
MAE = metrics.mean_absolute_error(y_test,pred_test)
MSE = metrics.mean_squared_error(y_test,pred_test)

# %%
print("mean absolute error:",MAE)
print("mean squared error:",MSE)
# Out:
# mean absolute error: 0.2350553719382946
# mean squared error: 0.09452460330687464

# %%
from math import sqrt
rmse = sqrt(MSE)
print("Root Mean Squared Error:",rmse)
# Out:
# Root Mean Squared Error: 0.3074485376561005

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.linear_model import Lasso
parameters = {'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(2,10))}

ls = Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 2}

# %%
ls = Lasso(alpha=0.0001,random_state=2)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls = ls.predict(x_test)

# %%
lss = r2_score(y_test,pred_ls)
lss
# Out:
# 0.4212144685281113

# %%
cv_score = cross_val_score(ls,x,y,cv=7)
cv_mean = cv_score.mean()
cv_mean
# Out:
# 0.013229044627865576

# %%
# WITH RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(criterion="mse",max_features="auto",max_depth=3,min_samples_leaf=2)
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_dec = rf.predict(x_test)

# %%
rfs = r2_score(y_test,pred_dec)
print('R2 Score:',rfs*100)
rf_score = cross_val_score(rf,x,y,cv=7)
rfc = rf_score.mean()
print("Cross val Score :",rfc*100)
# Out:
# R2 Score: 50.110190965654844
# Cross val Score : 12.269346710669648

# %%
# WITH ADABOOST

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import RandomizedSearchCV

# %%
params = {'n_estimators':[47,50,60,70],'learning_rate':[0.25,0.30,0.40]}

# %%
rnd_srch = RandomizedSearchCV(AdaBoostRegressor(),cv=3,param_distributions=params)

# %%
rnd_srch.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=3, estimator=AdaBoostRegressor(),
#                    param_distributions={'learning_rate': [0.25, 0.3, 0.4],
#                                         'n_estimators': [47, 50, 60, 70]})

# %%
rnd_srch.best_estimator_
# Out:
# AdaBoostRegressor(learning_rate=0.25)

# %%
ada = AdaBoostRegressor(learning_rate=0.25,n_estimators=95)

# %%
ada.fit(x_train,y_train)
# Out:
# AdaBoostRegressor(learning_rate=0.25, n_estimators=95)

# %%
y_pred = ada.predict(x_test)

print(r2_score(y_test,y_pred))
# Out:
# 0.5189639378264091

# %%
cv_score = cross_val_score(ada,x,y,cv=7)
cv_mean = cv_score.mean()
cv_mean
# Out:
# 0.0045824386826696884

# %%
# so as the diff between the r2 score and cross val score is less in RANDOM FORERST ALGO so we used rf to predict our model

# %%
# saving the model for later prediction
import pickle

# %%
filename = 'AVERAGEPRICE_AVACADO.pickle'
pickle.dump(rf,open(filename,'wb'))

# %% [markdown]
# # hence my model is completed and ready to predict the average price of avocadoes

# %% [markdown]
# # Now we have to build a model for the output - REGION

# %%
data
# Out:
#        AveragePrice     4046       4225    4770  Small Bags  Large Bags  \
# 0              1.33  1036.74   54454.85   48.16     8603.62       93.25
# 1              1.35   674.28   44638.81   58.33     9408.07       97.49
# 2              0.93   794.70  109149.67  130.50     8042.21      103.14
# 3              1.08  1132.00   71976.41   72.58     5677.40      133.76
# 4              1.28   941.48   43838.39   75.78     5986.26      197.69
# ...             ...      ...        ...     ...         ...         ...
# 18244          1.63  2046.96    1529.20    0.00    13066.82      431.85
# 18245          1.71  1191.70    3431.50    0.00     8940.04      324.80
# 18246          1.87  1191.92    2452.79  727.94     9351.80       42.31
# 18247          1.93  1527.63    2981.04  727.01    10919.54       50.00
# 18248          1.62  2894.77    2356.13  224.53    11988.14       26.01
#
#        XLarge Bags  type  year  region
# 0              0.0     0  2015       0
# ...

# %%
# seprating the columns into features and target

x= data.drop("region",axis=1)
y= data["region"]

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
from sklearn.metrics import accuracy_score,confusion_matrix, roc_curve, roc_auc_score,classification_report
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=.25)

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
pred_lr=lr.predict(x_test)
print("Accuracy",accuracy_score(y_test,pred_lr)*100)
print('-------------------')
print(confusion_matrix(y_test,pred_lr))
print(classification_report(y_test,pred_lr))
# Out:
# Accuracy 17.554240631163708
# -------------------
# [[ 0  0  2 ...  0  0  0]
#  [ 0  9  0 ...  0  4  0]
#  [ 0  0 51 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 54  0  0]
#  [ 0  0  0 ... 14 42  0]
#  [ 0  0  3 ...  1 10  4]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        83
#            1       0.14      0.10      0.12        88
#            2       0.28      0.56      0.38        91
#            3       0.00      0.00      0.00        77
#            4       0.25      0.13      0.17        98
#            5       0.18      0.15      0.16        93
#            6       0.14      0.38      0.20        92
#            7       0.00      0.00      0.00       103
#            8       0.60      0.47      0.53        75
#            9       0.13      0.60      0.21        81
#           10       0.00      0.00      0.00        82
#           11       0.08      0.01      0.02        87
# ...

# %%
Test_accuracy = accuracy_score(y_test,pred_lr)

# %%
from sklearn.model_selection import cross_val_score

# %%
scr_lr = cross_val_score(lr,x,y,cv=5)
print("Cross Validation Score of logistic regression model is :-",scr_lr.mean())
# Out:
# Cross Validation Score of logistic regression model is :- 0.13923440837609852

# %%
# now we trying with Decision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
pred_dt=dt.predict(x_test)
print("Accuracy",accuracy_score(y_test,pred_dt)*100)
print('-------------------------')
print(confusion_matrix(y_test,pred_dt))
print(classification_report(y_test,pred_dt))
# Out:
# Accuracy 80.49528818759588
# -------------------------
# [[62  0  0 ...  0  0  0]
#  [ 0 72  0 ...  0  0  1]
#  [ 0  0 82 ...  0  0  2]
#  ...
#  [ 0  0  0 ... 87  0  0]
#  [ 0  0  0 ...  0 83  0]
#  [ 0  2  2 ...  0  0 65]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.75      0.78        83
#            1       0.67      0.82      0.74        88
#            2       0.85      0.90      0.87        91
#            3       0.78      0.77      0.77        77
#            4       0.92      0.86      0.89        98
#            5       0.65      0.68      0.66        93
#            6       0.97      0.99      0.98        92
#            7       0.92      0.86      0.89       103
#            8       0.96      0.95      0.95        75
#            9       0.73      0.81      0.77        81
#           10       0.59      0.66      0.62        82
#           11       0.81      0.86      0.83        87
# ...

# %%
scr_dt = cross_val_score(dt,x,y,cv=5)
print("Cross Validation Score of Decision TREE model is :-",scr_dt.mean())
# Out:
# Cross Validation Score of Decision TREE model is :- 0.5557482965871678

# %%
# now check with random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
pred_rf=rf.predict(x_test)
print("Accuracy",accuracy_score(y_test,pred_rf)*100)
print('=======================================')
print(confusion_matrix(y_test,pred_rf))
print(classification_report(y_test,pred_rf))
# Out:
# Accuracy 90.94893710278326
# ...
# [[79  0  0 ...  0  0  0]
#  [ 0 57  0 ...  0  0  0]
#  [ 0  0 64 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 73  0  0]
#  [ 0  0  0 ...  0 89  0]
#  [ 0  0  0 ...  0  0 72]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88        87
#            1       0.81      0.83      0.82        69
#            2       0.98      1.00      0.99        64
#            3       0.95      0.84      0.89       106
#            4       0.98      0.99      0.98        84
#            5       0.85      0.77      0.81        87
#            6       0.97      1.00      0.99        78
#            7       0.89      0.94      0.91        77
#            8       0.96      0.98      0.97        90
#            9       0.95      0.91      0.93        77
#           10       0.90      0.85      0.88        89
#           11       0.89      0.90      0.89        79
#           12       0.96      1.00      0.98        98
# ...

# %%
scr_rf = cross_val_score(rf,x,y,cv=5)
print("Cross Validation Score of RANDOM FOREST model is :-",scr_rf.mean())
# Out:
# Cross Validation Score of RANDOM FOREST model is :- 0.6970142617418171

# %%
# now with SVC algo

# %%
from sklearn.svm import SVC

sv = SVC()
sv.fit(x_train,y_train)

pred_sv=sv.predict(x_test)
print("Accuracy",accuracy_score(y_test,pred_sv)*100)

print('=========================================')
print(confusion_matrix(y_test,pred_sv))
print(classification_report(y_test,pred_sv))
# Out:
# Accuracy 19.044488275257507
# ...
# [[ 0  0  0 ...  0  0  0]
#  [ 0 29  0 ...  0  0  3]
#  [ 0  0 27 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 60  0  0]
#  [ 0  0  0 ...  0 37  0]
#  [ 0  2  0 ...  0  0 34]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        87
#            1       0.27      0.42      0.33        69
#            2       0.30      0.42      0.35        64
#            3       0.00      0.00      0.00       106
#            4       0.17      0.08      0.11        84
#            5       0.00      0.00      0.00        87
#            6       0.89      0.50      0.64        78
#            7       0.00      0.00      0.00        77
#            8       0.98      0.46      0.62        90
#            9       0.00      0.00      0.00        77
#           10       0.00      0.00      0.00        89
#           11       0.53      0.25      0.34        79
#           12       0.84      0.33      0.47        98
# ...

# %%
scr = cross_val_score(sv,x,y,cv=5)
print("Cross Validation Score of SVC model is :-",scr.mean())
# Out:
# Cross Validation Score of SVC model is :- 0.2184671349253126

# %%
# so the difference between the cross val score and the accuracy score is  minimun for the Random forest SO WE USED THIS algo


# BUT BEFORE USED HYPERPARAMETER TUNING WITH GRIDSEARCHCV

# %%
parameters = {'max_depth':range(2,4),'min_samples_leaf':range(2,4),'min_samples_split':range(2,4),'n_estimators':[20,30,60,80]}

clf = GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'max_depth': 3, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 80}

# %%
rf = RandomForestClassifier(max_depth= 3, min_samples_leaf=2, min_samples_split= 2, n_estimators= 80)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=3, min_samples_leaf=2, n_estimators=80)

# %%
y_pred = lr.predict(x_test)

# %%
cfm = confusion_matrix(y_test,pred_rf)
cfm
# Out:
# array([[79,  0,  0, ...,  0,  0,  0],
#        [ 0, 57,  0, ...,  0,  0,  0],
#        [ 0,  0, 64, ...,  0,  0,  0],
#        ...,
#        [ 0,  0,  0, ..., 73,  0,  0],
#        [ 0,  0,  0, ...,  0, 89,  0],
#        [ 0,  0,  0, ...,  0,  0, 72]], dtype=int64)

# %%
print(classification_report(y_test,pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88        87
#            1       0.81      0.83      0.82        69
#            2       0.98      1.00      0.99        64
#            3       0.95      0.84      0.89       106
#            4       0.98      0.99      0.98        84
#            5       0.85      0.77      0.81        87
#            6       0.97      1.00      0.99        78
#            7       0.89      0.94      0.91        77
#            8       0.96      0.98      0.97        90
#            9       0.95      0.91      0.93        77
#           10       0.90      0.85      0.88        89
#           11       0.89      0.90      0.89        79
#           12       0.96      1.00      0.98        98
#           13       0.85      0.88      0.86        89
#           14       0.92      0.91      0.92        94
#           15       0.99      0.97      0.98        89
# ...

# %%
print("ACCURACY",accuracy_score(y_test,pred_rf))
# Out:
# ACCURACY 0.9094893710278326

# %%
# so after tuning, its accuracy is  increased by a very few extent so now our RF model is ready to predict

# %%
# saving the model for later prediction
import pickle

# %%
filename = 'ReGION OF AVOCADO.pickle'
pickle.dump(rf,open(filename,'wb'))

# %%
# model is ready to predict
